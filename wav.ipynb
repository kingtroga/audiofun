# %%
# !pip install pipwin
# !pipwin install pyaudio
# !pip install playsound pyaudio pydub ffmpeg-python
# Out:
# ...
# Package `pyaudio` found in cache
# ...
# https://download.lfd.uci.edu/pythonlibs/a4hvik9m/PyAudio-0.2.11-cp39-cp39-win_amd64.whl
# PyAudio-0.2.11-cp39-cp39-win_amd64.whl
# ...

# %%
from pydub import AudioSegment

# %%
# Import the .mp3 file
mp3_file = AudioSegment.from_file(file=r"C:\Users\TARI\Documents\GitHub\audiofun\Dumebi_slow_and_reverb.mp3", format="mp3")

# Export the .mp3 file as wav
# format is "mp3" by default
mp3_file.export(out_f="dumebi.wav", format="wav")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\TARI\Documents\GitHub\audiofun\wav.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/TARI/Documents/GitHub/audiofun/wav.ipynb#ch0000001?line=0'>1</a> # Import the .mp3 file
# ----> <a href='vscode-notebook-cell:/c%3A/Users/TARI/Documents/GitHub/audiofun/wav.ipynb#ch0000001?line=1'>2</a> mp3_file = AudioSegment.from_file(file=r"C:\Users\TARI\Documents\GitHub\audiofun\Dumebi_slow_and_reverb.mp3", format="mp3")
#       <a href='vscode-notebook-cell:/c%3A/Users/TARI/Documents/GitHub/audiofun/wav.ipynb#ch0000001?line=3'>4</a> # Export the .mp3 file as wav
#       <a href='vscode-notebook-cell:/c%3A/Users/TARI/Documents/GitHub/audiofun/wav.ipynb#ch0000001?line=4'>5</a> # format is "mp3" by default
# ...
